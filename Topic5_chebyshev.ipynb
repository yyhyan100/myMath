# %%
# plot of the weight function
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,0.999,30)
w=1/np.sqrt(1-x**2)
plt.xlim(0,1)
plt.ylim(1,2)
plt.scatter(x,w)

# %%
# plot the zeros of TN(x):
from myMath.chebyshev import chebyshev_approximation
import matplotlib.pyplot as plt
ca=chebyshev_approximation()
y=ca.get_zeros(20)
plt.scatter(range(20),y)

# %% [markdown]
# ### Chebyshev approximation

# %%
# use Chebyshev polynomials for the approximation:
from myMath.chebyshev import chebyshev_approximation
import matplotlib.pyplot as plt
from math import *
import numpy as np
ca=chebyshev_approximation()
x=ca.get_zeros(20)
y=np.sin(x)+np.exp(x)
ca.train(x,y)
x1=np.linspace(0,1,15)
y1=ca.predict(x1)
plt.plot(x1,y1)
plt.scatter(x,y)
